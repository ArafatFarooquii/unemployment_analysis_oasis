# %% [markdown]
# **OASIS INFOBYTE INTERNSHIP**
# Domain- **Datascience**
# Name- **Arafat Farooqui**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data=pd.read_csv('/content/Unemployment in India.csv')
data=pd.read_csv('/content/Unemployment_Rate_upto_11_2020.csv')

# %%
data.head()
# Out:
#            states         Date Frequency  Estimated Unemployment rate  \
# 0  Andhra Pradesh   31-01-2020         M                         5.48
# 1  Andhra Pradesh   29-02-2020         M                         5.83
# 2  Andhra Pradesh   31-03-2020         M                         5.79
# 3  Andhra Pradesh   30-04-2020         M                        20.51
# 4  Andhra Pradesh   31-05-2020         M                        17.43
#
#    Estimated Employed  Estimated Labour Participation Rate Region  Longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
# 3            11336911                                33.10  South    15.9129
# 4            12988845                                36.46  South    15.9129
#
#    Latitude
# 0     79.74
# 1     79.74
# 2     79.74
# 3     79.74
# 4     79.74

# %%
data.tail()
# Out:
#           states         Date Frequency  Estimated Unemployment rate  \
# 262  West Bengal   30-06-2020         M                         7.29
# 263  West Bengal   31-07-2020         M                         6.83
# 264  West Bengal   31-08-2020         M                        14.87
# 265  West Bengal   30-09-2020         M                         9.35
# 266  West Bengal   31-10-2020         M                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region  \
# 262            30726310                                40.39   East
# 263            35372506                                46.17   East
# 264            33298644                                47.48   East
# 265            35707239                                47.73   East
# 266            33962549                                45.63   East
#
#      Longitude  Latitude
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# ...

# %%
data.shape
# Out:
# (267, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   states                               267 non-null    object
#  1   Date                                 267 non-null    object
#  2   Frequency                            267 non-null    object
#  3   Estimated Unemployment rate          267 non-null    float64
#  4   Estimated Employed                   267 non-null    int64
#  5   Estimated Labour Participation Rate  267 non-null    float64
#  6   Region                               267 non-null    object
#  7   Longitude                            267 non-null    float64
#  8   Latitude                             267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
data.describe()
# Out:
#        Estimated Unemployment rate  Estimated Employed  \
# count                   267.000000        2.670000e+02
# mean                     12.236929        1.396211e+07
# std                      10.803283        1.336632e+07
# min                       0.500000        1.175420e+05
# 25%                       4.845000        2.838930e+06
# 50%                       9.650000        9.732417e+06
# 75%                      16.755000        2.187869e+07
# max                      75.850000        5.943376e+07
#
#        Estimated Labour Participation Rate   Longitude    Latitude
# count                           267.000000  267.000000  267.000000
# mean                             41.681573   22.826048   80.532425
# std                               7.845419    6.270731    5.831738
# min                              16.770000   10.850500   71.192400
# 25%                              37.265000   18.112400   76.085600
# ...

# %%
x=data['Region']

# %%
print(x)
# Out:
# 0      South
# 1      South
# 2      South
# 3      South
# 4      South
#        ...
# 262     East
# 263     East
# 264     East
# 265     East
# 266     East
# Name: Region, Length: 267, dtype: object

# %%
y=data['Estimated Unemployment rate']

# %%
print(y)
# Out:
# 0       5.48
# 1       5.83
# 2       5.79
# 3      20.51
# 4      17.43
#        ...
# 262     7.29
# 263     6.83
# 264    14.87
# 265     9.35
# 266     9.98
# Name: Estimated Unemployment rate, Length: 267, dtype: float64

# %%
data2=data.iloc[:,3]

# %%
print(data2)
# Out:
# 0       5.48
# 1       5.83
# 2       5.79
# 3      20.51
# 4      17.43
#        ...
# 262     7.29
# 263     6.83
# 264    14.87
# 265     9.35
# 266     9.98
# Name: Estimated Unemployment rate, Length: 267, dtype: float64

# %%
fg=px.bar(data,x='states',y='Estimated Unemployment rate',color='Region',title='unemployment rate (state wise) by bar graph',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fg=px.bar(data,x='Region',y='Estimated Unemployment rate',color='Region',title='unemployment rate (state wise) by bar graph',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fg=px.box(data,x='states',y='Estimated Unemployment rate',color='Region',title='unemployment rate (state wise) by bar graph',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fg=px.box(data,x='Region',y='Estimated Unemployment rate',color='Region',title='unemployment rate (state wise) by bar graph',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fg=px.histogram(data,x='states',y='Estimated Unemployment rate',color='Region',title='unemployment rate (state wise) by bar graph',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fg=px.histogram(data,x='Region',y='Estimated Unemployment rate',color='Region',title='unemployment rate (state wise) by bar graph',template='plotly')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
